# %%
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df
# Out:
#     Unnamed: 0   Unnamed: 1  \
# 0  Interviewer  Interviewee
# 1        Mandy       Laurel
# 2        Mandy        Kevin
# 3        Mandy         Mera
# 4        David       Thomas
# 5        David         Nick
# 6        David       Ayushi
# 7        Tammy        Cassy
# 8        Tammy      Shruthi
# 9        Tammy          Ava
#
#                                            Questions  \
# 0    1: Do you have a reusable bottle? Why/ Why not?
# 1                         Yes for going out studying
# 2                yeah I have a reusable water bottle
# 3  Yes, good for environment and not wasting anyt...
# 4  Yes because it’s cost effective - dont need to...
# 5  Yes, so he can take it to the gym without worr...
# 6            Yes, it's convenient to take to school.
# 7  yes because i found it in my house and it’s co...
# 8
# yes because it’s good for the environment it’...
# 9  yes because it's insulating and keeps her wate...
#
#                                           Unnamed: 3  \
# 0                 2: What brand is your bottle? Why?
# 1              Hydro Flask because I like the colors
# 2                                          camelback
# 3  Hydro Flask; good for environment and not wast...
# 4  Hydro Flask, no particular reason. Just though...
# 5  Hydro Flask, likes the color options and shape...
# 6                                              Other
# 7  thermoflask, no reason but it's off-brand hydr...
# 8                          hydroflask, it's reliable
# 9                                         hydroflask
#
#                                           Unnamed: 4  \
# 0  3: Where do you drink from the bottle? Can you...
# 1  Presses straw tab to open spout then sips. No ...
# 2                                                NaN
# 3                                              Straw
# 4  The opening at the top. He uses both hands to ...
# 5  Drinks from an opening with a suction at the t...
# 6  Straw at the top. Flips it open by pushing on ...
# 7  Drinks from a little opening at the top that s...
# 8  drinks from the flip-up straw holding the bott...
# 9  from the sippy lid opening at the top that pul...
#
#                                           Unnamed: 5  \
# 0  4: How do you hold your bottle when you have i...
# 1            She holds the convenient handle because
# 2                                                NaN
# 3  Uses her hold hand to grip the body. \nWhy? Di...
# 4  Wraps a couple fingers around the loop at the ...
# 5  Holds it by the handle. Has it in the water bo...
# 6  By the loop at the top. Fingers easily fit thr...
# 7  the handle/hook at the top of the water bottle...
# 8  the little loop at the top, it's a big water b...
# 9  by the handle at the top but also since it's r...
#
#                                           Unnamed: 6  \
# 0  5: Do you use your water bottle in a way that ...
# 1                                  No just ice water
# 2  sometimes I’ll put my phone up against it as l...
# 3                                Rolling out muscles
# 4  Has sticker on water bottle - form of self exp...
# 5                                                 No
# 6                                  Yes, paperweight.
# 7                         self defense, if necessary
# 8  not really but one time for a beverage that wa...
# 9                                                 no
#
#                                           Unnamed: 7  \
# 0  6: When was the last time you experienced an i...
# 1     Cons: pulling out during class loud metal echo
# 2  have not experienced much inconvenience with e...
# 3  Loud when she dropped it, slippery (the body)\...
# 4  I really hate when I accidentally drop this th...
# 5  Leaks a little from the top. Thinks the sealin...
# 6  Is damaged easily, the surface is covered in s...
# 7  when it's in her backpack and it makes the wei...
# 8  it’s sometimes leaky because theres no protect...
# 9
# flying out during thanksgiving break towards ...
#
#                                           Unnamed: 8  \
# 0  7: How often do you drink from your water bott...
# 1                                                NaN
# 2  how often I use waterbottle: 3/10\n\nhow activ...
# 3  10/10 use: at school, working out, in car\n6/6...
# 4  Tries to drink from it at least once a day. Sa...
# 5  Only when going to the gym, which is about 3-4...
# 6  Almost all the time, the straw makes it much m...
# 7  once an hour, and she has had her bottle for 3...
# 8  multiple times an hour, she's had it for aroun...
# 9  once every 2 hours, tries to drink from it fre...
#
#                                           Unnamed: 9
# 0           8. How much volume can your bottle hold?
# 1  32 Oz. Easy to tell how full by shaking and li...
# 2                                              25 Oz
# 3                                              32 Oz
# 4                                              24 Oz
# 5                                              16 oz
# 6                                              24 Oz
# 7                                              24 oz
# 8                                              40 oz
# 9                                              24 oz

# %%
df_questions = pd.DataFrame(df.iloc[0])
df_questions = df_questions.reset_index()
df_questions.index = np.arange(1, len(df_questions) + 1)
df_questions = df_questions.rename(columns={'0': 'Questions'})
df_questions = df_questions.drop(columns=['index'])
df_questions
# Out:
#                                                     0
# 1                                         Interviewer
# 2                                         Interviewee
# 3     1: Do you have a reusable bottle? Why/ Why not?
# 4                  2: What brand is your bottle? Why?
# 5   3: Where do you drink from the bottle? Can you...
# 6   4: How do you hold your bottle when you have i...
# 7   5: Do you use your water bottle in a way that ...
# 8   6: When was the last time you experienced an i...
# 9   7: How often do you drink from your water bott...
# 10           8. How much volume can your bottle hold?

# %%
df_brand = pd.DataFrame()
brands = ['Hydro Flask', 'Camelback', 'Thermoflask', 'Other']
df_brand['Brands'] = brands
df_brand['Count'] = [6, 1, 1, 1]
df_brand
# Out:
#         Brands  Count
# 0  Hydro Flask      6
# 1    Camelback      1
# 2  Thermoflask      1
# 3        Other      1

# %%
plt.figure(figsize=(5, 5))
ax = df_brand.plot.bar(x='Brands', y='Count', rot=0)

plt.xlabel("Brands", labelpad = 15)
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
volume = df['Unnamed: 9']
df_vol = pd.DataFrame(volume)
df_vol = df_vol.drop(0)
df_vol = df_vol.rename(columns={'Unnamed: 9': 'Volume'})
df_vol['Volume'] = df_vol.Volume.str.extract('(\d+)')
df_vol.sort_values('Volume', inplace=True)
df_vol
# Out:
#   Volume
# 5     16
# 4     24
# 6     24
# 7     24
# 9     24
# 2     25
# 1     32
# 3     32
# 8     40

# %%
plt.hist(df_vol['Volume'], density=False, bins=5)
plt.ylabel('Count')
plt.xlabel('Volume (Ounces)');
